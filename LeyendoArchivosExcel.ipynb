# %% [markdown]
# 2. Excel | pd.read_excel()
# Uno de los tipos de archivo más utilizados para datos es el archivo de tipo Excel (.xlsx).
#
# Dato importante: Para leer archivos en Excel con Pandas, es necesario tener instalada la biblioteca openpyxl. La distribución Anaconda trae esta biblioteca preinstalada, en caso de no usar Anaconda es necesario intalarla.
# pip install openpyxl

# %%
import pandas as pd

# %%
pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
df = pd.read_excel(io="datasets/DatosVentas.xlsx", sheet_name="datos_ventas")

# %%
df.head()
# Out:
#   CodigoTienda  Tienda  CodigoProducto DescripcionProduto  Matricula  \
# 0     TIENDA01  Matriz           10001         Smartphone  123456111
# 1     TIENDA01  Matriz           10001         Smartphone  123456111
# 2     TIENDA01  Matriz           10002             Tablet  123456333
# 3     TIENDA01  Matriz           10002             Tablet  123456333
# 4     TIENDA01  Matriz           10003          Televisor  123456333
#
#   NombreVendedor FechaDeVenta  PrecioUnitario  Cantidad  Valorventa
# 0  Jose Martinez   2024-10-19            1500         1        1500
# 1  Jose Martinez   2024-11-16            1500         2        3000
# 2   Jorge Mateus   2024-02-20            1000         2        2000
# 3   Jorge Mateus   2024-06-03            1000         3        3000
# 4   Jorge Mateus   2024-02-01            3500         3       10500

# %%
df1= pd.read_excel(io="datasets/DatosVentas.xlsx", sheet_name="funcionarios")

# %%
df1.head()
# Out:
#    Matricula NombreVendedor
# 0  123456111  Jose Martinez
# 1  123456333   Jorge Mateus
# 2  123456222   Maria García
