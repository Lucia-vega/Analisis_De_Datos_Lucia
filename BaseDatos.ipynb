# %%
import pandas as pd
# permite conectar a la base de datos
import sqlite3

# %%
conn = sqlite3.connect('datasets/ventas.db')

# %%
#Crean un cursor para ejecutar consultas SQl , que sirve 
# para interactuar con la base de datos
cursor = conn.cursor()

# %%
df=pd.read_sql_query(sql= "SELECT * FROM pedidos;", con=conn)

# %%
df.head()
# Out:
#    id codigo_tienda  tienda  codigo_producto descripcion_producto  matricula  \
# 0   1      TIENDA01  Matriz            10001           Smartphone  123456111
# 1   2      TIENDA01  Matriz            10001           Smartphone  123456111
# 2   3      TIENDA01  Matriz            10001           Smartphone  123456111
# 3   4      TIENDA01  Matriz            10001           Smartphone  123456111
# 4   5      TIENDA01  Matriz            10001           Smartphone  123456111
#
#         vendedor fecha_venta  precio_unitario  cantidad  valor_venta
# 0  Jose Martinez    19/10/24           1500.0         1       1500.0
# 1  Jose Martinez    19/10/24           1500.0         1       1500.0
# 2  Jose Martinez    19/10/24           1500.0         1       1500.0
# 3  Jose Martinez    19/10/24           1500.0         1       1500.0
# 4  Jose Martinez    19/10/24           1500.0         1       1500.0

# %%
type(df)
# Out:
# pandas.DataFrame
