# %%
import pandas as pd

# %%
data= {
    'a': [1,2,3],
    'b': [10,20,30],
}

df = pd.DataFrame(data)
df
# las laves representan las columnas
# los valores representan las filas
# Out:
#    a   b
# 0  1  10
# 1  2  20
# 2  3  30

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
#Aceder a una columna
#UNa columna es una serie de pandas
df['a']
# Out:
# 0    1
# 1    2
# 2    3
# Name: a, dtype: int64

# %% [markdown]
# CARGANDO DATOS CON PANDAS

# %%
df =pd.read_csv("datos_ventas.csv", sep =";")

# %%
df.head(10)
# Out:
#   CodigoTienda  Tienda  CodigoProducto DescripcionProduto  Matricula  \
# 0     TIENDA01  Matriz           10001         Smartphone  123456111
# 1     TIENDA01  Matriz           10001         Smartphone  123456111
# 2     TIENDA01  Matriz           10002             Tablet  123456333
# 3     TIENDA01  Matriz           10002             Tablet  123456333
# 4     TIENDA01  Matriz           10003          Televisor  123456333
# 5     TIENDA01  Matriz           10004           Lavadora  123456222
# 6     TIENDA01  Matriz           10005             Laptop  123456222
# 7     TIENDA01  Matriz           10005             Laptop  123456222
# 8     TIENDA01  Matriz           10007          Mezclador  123456222
# 9     TIENDA01  Matriz           10008           Cafetera  123456222
#
#   NombreVendedor FechaDeVenta  PrecioUnitario  Cantidad  Valorventa
# 0  Jose Martinez     19/10/24            1500         1        1500
# 1  Jose Martinez     16/11/24            1500         2        3000
# ...

# %%
type(df )
# Out:
# pandas.DataFrame

# %%
type(df["Tienda"])
# Out:
# pandas.Series

# %%
df["Tienda"]
# Out:
# 0     Matriz
# 1     Matriz
# 2     Matriz
# 3     Matriz
# 4     Matriz
# 5     Matriz
# 6     Matriz
# 7     Matriz
# 8     Matriz
# 9     Matriz
# 10    Matriz
# 11    Matriz
# 12    Matriz
# 13    Matriz
# 14    Matriz
# 15    Matriz
# 16    Matriz
# 17    Matriz
# 18    Matriz
# 19    Matriz
# 20    Matriz
# 21    Matriz
# 22    Matriz
# 23    Matriz
# 24    Matriz
# 25    Matriz
# 26    Matriz
# 27    Matriz
# 28    Matriz
# 29    Matriz
# 30    Matriz
# 31    Matriz
# 32    Matriz
# Name: Tienda, dtype: str
