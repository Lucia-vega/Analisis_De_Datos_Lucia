# %% [markdown]
# Dato importante: Para leer archivos con formato html con Pandas, es necesario tener instalada la biblioteca lxml.
# pip install lxml

# %%
pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (6.0.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
import requests

# %%
df = pd.read_html("https://www.365scores.com/es/news/mejores-jugadores-ranking/")
df = tablas[0]  # eliges la primera tabla

# %%
len(df)
# Out:
# 25

# %%
df
# Out:
#     Posición             Jugador        País
# 0          1        Lionel Messi   Argentina
# 1          2   Cristiano Ronaldo    Portugal
# 2          3   Ronaldinho Gaúcho      Brasil
# 3          4     Zinedine Zidane     Francia
# 4          5      Andrés Iniesta      España
# 5          6      Xavi Hernández      España
# 6          7       Thierry Henry     Francia
# 7          8                Kaká      Brasil
# 8          9         Luis Suárez     Uruguay
# 9         10          Dani Alves      Brasil
# 10        11        Andrea Pirlo      Italia
# 11        12        Philipp Lahm    Alemania
# 12        13        Sergio Ramos      España
# 13        14         Luka Modric     Croacia
# 14        15     Fabio Cannavaro      Italia
# 15        16    Gianluigi Buffon      Italia
# 16        17    Ronaldo Fenomeno      Brasil
# 17        18  Zlatan Ibrahimovic      Suecia
# 18        19       Mohamed Salah      Egipto
# 19        20        Wayne Rooney  Inglaterra
# 20        21           Luis Figo    Portugal
# 21        22              Neymar      Brasil
# 22        23       Kylian Mbappé     Francia
# 23        24          John Terry  Inglaterra
# 24        25       Karim Benzema     Francia

# %%
type(df )
# Out:
# pandas.DataFrame
